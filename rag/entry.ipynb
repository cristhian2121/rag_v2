# %%
from langchain_chroma import Chroma
from langchain_community.document_loaders import PyPDFLoader, DirectoryLoader

import os

# %% [markdown]
# ### Load files

# %%
current_dir = os.path.dirname(os.path.abspath("."))
print("current directory", current_dir)
loader = DirectoryLoader(f"{current_dir}/rag/files", glob="*.pdf", loader_cls=PyPDFLoader)
# Out:
# current directory /Users/roshi/Documents/AI/courses/platzy_agents_ai

# %%
pages = loader.load()
pages
# Out:
# [Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': 'PyPDF', 'creationdate': 'D:20240912034157', 'source': '/Users/roshi/Documents/AI/courses/platzy_agents_ai/rag/files/informe_analisis_ventas_tienda_abc.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Informe de Análisis de Ventas - Tienda ABC\nEste informe presenta un análisis detallado de las ventas realizadas en la Tienda ABC durante el\núltimo trimestre. El objetivo de este informe es identificar tendencias, analizar el rendimiento de los\nproductos, y proponer recomendaciones para mejorar las ventas en el próximo período.\n1. Rendimiento General de Ventas\nEn el último trimestre, las ventas totales alcanzaron un valor de $150,000, con un incremento del\n15% respecto al trimestre anterior. El número total de transacciones fue de 2,500, lo que representa\nun promedio de 833 transacciones por mes.\n2. Análisis por Categoría de Producto\nLas siguientes categorías de productos se analizaron según su rendimiento en ventas:\n- Ropa: Representa el 40% de las ventas totales, con un valor de $60,000.\n- Calzado: Contribuye con el 30% de las ventas, alcanzando $45,000.\n- Accesorios: Generaron $30,000, representando el 20% de las ventas.\n- Otros: El 10% restante, equivalente a $15,000, proviene de productos diversos.\n3. Productos más Vendidos\nLos siguientes productos fueron los más vendidos durante el trimestre:\n- Camiseta Básica: 500 unidades vendidas, con un total de $10,000 en ingresos.\n- Zapatos Deportivos: 300 unidades vendidas, generando $18,000 en ingresos.\n- Reloj de Pulsera: 200 unidades vendidas, con un total de $20,000 en ingresos.\n4. Recomendaciones\nPara incrementar las ventas en el próximo trimestre, se sugieren las siguientes acciones:'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': 'PyPDF', 'creationdate': 'D:20240912034157', 'source': '/Users/roshi/Documents/AI/courses/platzy_agents_ai/rag/files/informe_analisis_ventas_tienda_abc.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='- Lanzar promociones especiales para productos de la categoría de accesorios.\n- Optimizar la presencia online de la tienda para captar más clientes a través de redes sociales.\n- Realizar campañas de fidelización para los clientes recurrentes, ofreciendo descuentos exclusivos.'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': 'PyPDF', 'creationdate': 'D:20240912034447', 'source': '/Users/roshi/Documents/AI/courses/platzy_agents_ai/rag/files/investigacion_ia_medicina.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Investigación Científica: Impacto de la IA en la Medicina\nEste documento explora el impacto de la inteligencia artificial (IA) en el campo de la medicina. A lo\nlargo de los últimos años, la IA ha demostrado ser una herramienta poderosa para mejorar el\ndiagnóstico, optimizar los tratamientos y personalizar la atención médica. Este estudio analiza los\navances actuales y el potencial futuro de la IA en la medicina.\n1. Aplicaciones Actuales de la IA en Medicina\nLa IA está siendo utilizada en varios aspectos del cuidado de la salud, incluyendo:\n- Diagnóstico por imágenes: Algoritmos de IA analizan imágenes médicas para detectar\nenfermedades como el cáncer de pulmón o el Alzheimer.\n- Planificación de tratamientos: Herramientas de IA ayudan a personalizar los tratamientos en\nfunción del perfil genético de cada paciente.\n- Robótica en cirugía: Robots guiados por IA realizan procedimientos quirúrgicos con mayor\nprecisión y menor riesgo.\n2. Desafíos y Limitaciones\nA pesar de los avances, la integración de la IA en la medicina enfrenta desafíos importantes:\n- Privacidad de los datos: El uso de grandes volúmenes de datos médicos plantea preocupaciones\nsobre la privacidad y la seguridad.\n- Regulaciones: Es necesario que los gobiernos implementen marcos regulatorios adecuados para\ngarantizar el uso seguro y ético de la IA.\n- Confianza en los algoritmos: Muchos profesionales médicos son reacios a depender\ncompletamente de las decisiones de la IA, prefiriendo un enfoque mixto con el juicio humano.\n3. El Futuro de la IA en la Medicina'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': 'PyPDF', 'creationdate': 'D:20240912
orámica desde la cima.\n- Museo del Louvre: El museo más grande del mundo, hogar de obras maestras como la Mona Lisa\ny la Venus de Milo.\n- Catedral de Notre-Dame: Una catedral gótica que impresiona por su arquitectura y su historia.\n- Campos Elíseos y Arco del Triunfo: Pasea por esta avenida famosa y sube al Arco para una vista\nespectacular de la ciudad.\n2. Gastronomía Local\nParís es un paraíso para los amantes de la comida. Aquí te recomendamos algunos platos típicos y\nlugares para probarlos:\n- Croissants y pain au chocolat: Disfruta de estos deliciosos pasteles en cualquier café parisino.\n- Ratatouille: Un plato tradicional de verduras cocidas al horno, perfecto para vegetarianos.\n- Crêpes: Tanto dulces como saladas, las crêpes son una delicia en cualquier momento del día.\n- Restaurante Le Jules Verne: Ubicado en la Torre Eiffel, este restaurante ofrece una experiencia\ngastronómica inolvidable.'),
#  Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': 'PyPDF', 'creationdate': 'D:20240912034259', 'source': '/Users/roshi/Documents/AI/courses/platzy_agents_ai/rag/files/guia_viaje_descubre_paris.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content="3. Opciones de Transporte\nMoverse por París es fácil gracias a su eficiente sistema de transporte público. Las opciones\nincluyen:\n- Metro: El metro de París cuenta con 16 líneas que cubren la mayor parte de la ciudad.\n- Autobús: Ideal para disfrutar del paisaje mientras te desplazas de un lugar a otro.\n- Bicicletas: Puedes alquilar una bicicleta en las estaciones de Vélib' y explorar la ciudad sobre dos\nruedas.\n- Barcos Batobus: Una manera única de moverse por el río Sena y disfrutar de las vistas.\n4. Alojamiento Recomendado\nParís ofrece una amplia gama de alojamientos para todos los presupuestos. Algunas opciones\nrecomendadas son:\n- Hotel Le Meurice: Un hotel de lujo con vistas al Jardín de las Tullerías.\n- Hôtel des Grands Boulevards: Una opción boutique, perfecta para una estancia romántica.\n- Generator Hostel: Si buscas algo más económico, este moderno hostel es ideal para jóvenes\nviajeros.")]

# %% [markdown]
# #### split text

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=150, chunk_overlap=30)
splits = text_splitter.split_documents(pages)

# %%
print(f"Corpus size: {len(splits)}")
print(splits[0])
# Out:
# Corpus size: 69
# page_content='Informe de Análisis de Ventas - Tienda ABC
# Este informe presenta un análisis detallado de las ventas realizadas en la Tienda ABC durante el' metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': 'PyPDF', 'creationdate': 'D:20240912034157', 'source': '/Users/roshi/Documents/AI/courses/platzy_agents_ai/rag/files/informe_analisis_ventas_tienda_abc.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}

# %% [markdown]
# #### Embedding and vector db

# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

# %%
embedding_function = OpenAIEmbeddings()

vector_store = Chroma(
    collection_name="documents",
    embedding_function=embedding_function,
    persist_directory="./chroma_db",
)

vector_store.add_documents(splits)

retriever = vector_store.as_retriever()

# %% [markdown]
# #### Create chat model

# %%
system_prompt = """
You are a helpful assistant that can answer questions about the documents, also include emojis in your response.
you have the next {context}
"""

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0, max_tokens=150)

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableBranch
from operator import itemgetter

contextualize_q_system_promp = """
    Given a chat history and the latest user question 
    which might reference context in the chat history, 
    formulate a standalone question which can be understood 
    without the chat history. Do NOT answer the question,
    "just reformulate it if needed and otherwise return it as is.
    """

def make_history_aware_retriever(llm, retriever):
    # 1) Prompt that rewrites a context-dependent question into a standalone query
    contextualize_q_prompt = ChatPromptTemplate.from_messages([
        ("system", contextualize_q_system_promp),
        MessagesPlaceholder("chat_history"),
        ("human", "{input}"),
    ])

    # 2) LLM produces rewritten query as plain string
    contextualize_q_chain = contextualize_q_prompt | llm | StrOutputParser()

    # 3) Branch: if chat_history exists and is non-empty, rewrite then retrieve; else retrieve directly.
    history_aware_retriever = RunnableBranch(
        (lambda x: bool(x.get("chat_history")), contextualize_q_chain | retriever),
        (itemgetter("input") | retriever),
    )

    return history_aware_retriever

# %%
history_aware_retriever = make_history_aware_retriever(llm, retriever)

# %%
qa_prompt = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    MessagesPlaceholder("chat_history"),
    ("human", "{input}"),
])

# %%
from langchain_classic.chains.combine_documents import create_stuff_documents_chain
from langchain_classic.chains.retrieval import create_retrieval_chain

qa_chain = create_stuff_documents_chain(
    llm,
    qa_prompt,
)
rag_chain = create_retrieval_chain(
    history_aware_retriever,
    qa_chain,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 4
#       1 from langchain_classic.chains.combine_documents import create_stuff_documents_chain
#       2 from langchain_classic.chains.retrieval import create_retrieval_chain
# ----> 4 qa_chain = create_stuff_documents_chain(
#       5     llm,
#       6     qa_prompt,
#       7 )
#       8 rag_chain = create_retrieval_chain(
#       9     history_aware_retriever,
#      10     qa_chain,
#      11 )
#
# File ~/Documents/AI/courses/platzy_agents_ai/.venv/lib/python3.13/site-packages/langchain_classic/chains/combine_documents/stuff.py:84, in create_stuff_documents_chain(llm, prompt, output_parser, document_prompt, document_separator, document_variable_name)
#      25 def create_stuff_documents_chain(
#      26     llm: LanguageModelLike,
#      27     prompt: BasePromptTemplate,
#    (...)     32     document_variable_name: str = DOCUMENTS_KEY,
#      33 ) -> Runnable[dict[str, Any], Any]:
#      34     r"""Create a chain for passing a list of Documents to a model.
#      35
#      36     Args:
#    (...)     82         ```
#      83     """
# ---> 84     _validate_prompt(prompt, document_variable_name)
#      85     _document_prompt = document_prompt or DEFAULT_DOCUMENT_PROMPT
#      86     _output_parser = output_parser or StrOutputParser()
#
# File ~/Documents/AI/courses/platzy_agents_ai/.venv/lib/python3.13/site-packages/langchain_classic/chains/combine_documents/base.py:32, in _validate_prompt(prompt, document_variable_name)
#      27 if document_variable_name not in prompt.input_variables:
#      28     msg = (
#      29         f"Prompt must accept {document_variable_name} as an input variable. "
#      30         f"Received prompt with input variables: {prompt.input_variables}"
#      31     )
# ---> 32     raise ValueError(msg)
#
# ValueError: Prompt must accept context as an input variable. Received prompt with input variables: ['chat_history', 'input']

# %%
vector_store.similarity_search("Hello, world!", 2)
# Out:
# [Document(id='da844bc7-5bb5-4f76-a739-2b2b3a145388', metadata={'source': 'example.txt'}, page_content='Hello, world!'),
#  Document(id='44c9b550-62b4-4f16-a44c-20419c37c015', metadata={'source': 'example.txt'}, page_content='This is a test!')]

# %%
vector_store.similarity_search_with_score("Hello, world!", 2)
# Out:
# [(Document(id='da844bc7-5bb5-4f76-a739-2b2b3a145388', metadata={'source': 'example.txt'}, page_content='Hello, world!'),
#   0.0),
#  (Document(id='44c9b550-62b4-4f16-a44c-20419c37c015', metadata={'source': 'example.txt'}, page_content='This is a test!'),
#   0.2749747335910797)]
